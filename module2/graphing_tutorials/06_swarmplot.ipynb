# %% [markdown]
# # Seaborn: swarmplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
cars = sns.load_dataset('mpg').dropna()

cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Intro Visuals

# %%
import pandas as pd
import numpy as np

# %%
sns.set_style('white')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
blue, orange, green, red = sns.color_palette()[:4]

# %%
pts = np.array([1, 1, 1, 1, 1]) #, 2, 2, 3, 4, 4, 4, 4, 5, 5, 7])

plt.figure(figsize=(4,4))
sns.swarmplot(pts, color=green, size=15, linewidth=1, edgecolor='black')
sns.despine(left=True)
plt.xlim(0, 9)
plt.tight_layout();
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts = np.array([1, 1, 1, 1, 1, 2, 2]) #, 3, 4, 4, 4, 4, 5, 5, 7])

plt.figure(figsize=(4,4))
sns.swarmplot(pts, color=green, size=15, linewidth=1, edgecolor='black')
sns.despine(left=True)
plt.xlim(0, 9)
plt.tight_layout();
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts = np.array([1, 1, 1, 1, 1, 2, 2, 3]) #, 4, 4, 4, 4, 5, 5, 7])

plt.figure(figsize=(4,4))
sns.swarmplot(pts, color=green, size=15, linewidth=1, edgecolor='black')
sns.despine(left=True)
plt.xlim(0, 9)
plt.tight_layout();
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts = np.array([1, 1, 1, 1, 1, 2, 2, 3, 4, 4, 4, 4]) #, 5, 5, 7])

plt.figure(figsize=(4,4))
sns.swarmplot(pts, color=green, size=15, linewidth=1, edgecolor='black')
sns.despine(left=True)
plt.xlim(0, 9)
plt.tight_layout();
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts = np.array([1, 1, 1, 1, 1, 2, 2, 3, 4, 4, 4, 4, 5, 5]) #, 7])

plt.figure(figsize=(4,4))
sns.swarmplot(pts, color=green, size=15, linewidth=1, edgecolor='black')
sns.despine(left=True)
plt.xlim(0, 9)
plt.tight_layout();
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts = np.array([1, 1, 1, 1, 1, 2, 2, 3, 4, 4, 4, 4, 5, 5, 7])

plt.figure(figsize=(4,4))
sns.swarmplot(pts, color=green, size=15, linewidth=1, edgecolor='black')
sns.despine(left=True)
plt.xlim(0, 9)
plt.tight_layout();
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts = np.array([1, 1, 1, 1, 1, 2, 2, 3, 4, 4, 4, 4, 5, 5, 7])

plt.figure(figsize=(4,3))
sns.swarmplot(pts, color='black', size=15, linewidth=1, edgecolor='black')
sns.despine(left=True)
plt.xlim(0, 9)
plt.tight_layout();
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('whitegrid')

# %%
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %% [markdown]
# Filter down to only cars with even number of cylinders

# %%
cars = cars[cars.cylinders.isin([4,6,8])]

# %%
sns.swarmplot(cars.horsepower);
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(x=cars.origin, y=cars.horsepower);
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='origin', y='horsepower',
               data=cars
              );
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='origin', y='horsepower', hue='cylinders',
               data=cars
              );
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='origin', y='horsepower', hue='cylinders',
               data=cars, dodge=True
              );
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 43.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 46.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 28.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Swarmplot Overlay

# %%
usa = cars[cars.origin=='usa']

# %% [markdown]
# ### With Boxplot

# %%
sns.boxplot(x=usa.cylinders, y=usa.horsepower)
sns.swarmplot(x=usa.cylinders, y=usa.horsepower);
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x=usa.cylinders, y=usa.horsepower,
            whis=np.inf
           )
sns.swarmplot(x=usa.cylinders, y=usa.horsepower,
              color='black', alpha=0.5
             );
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### With Violinplot

# %%
sns.violinplot(x=usa.cylinders, y=usa.horsepower)
sns.swarmplot(x=usa.cylinders, y=usa.horsepower);
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 8.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x=usa.cylinders, y=usa.horsepower,
               scale='width'
              )
sns.swarmplot(x=usa.cylinders, y=usa.horsepower,
              color='white', size=4
             );

# %%
sns.violinplot(x=usa.cylinders, y=usa.horsepower,
               scale='width', inner=None, color='xkcd:forest green'
              )
sns.swarmplot(x=usa.cylinders, y=usa.horsepower,
              color='white', size=3
             );

# %% [markdown]
# ## Styling

# %% [markdown]
# ### linewidth, edgecolor

# %%
sns.swarmplot(cars.horsepower, linewidth=1);
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(cars.horsepower, linewidth=1, edgecolor='black');
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Matplotlib Scatter Properties: marker
#
# Check the [matplotlib scatter](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html) and the [marker style docs](https://matplotlib.org/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle) for more styling of the markers themselves

# %%
plt.figure(figsize=(8, 4))

sns.swarmplot(cars.horsepower, marker='*');
# Out:
# /home/kg3597wc/anaconda3/envs/dsci326/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Module 4 Homework
#
# ## More Walmart Cleaning
#
# The file **Walmart_United_States\_&\_Canada.csv** contains data on all
# Walmarts, Sam's Clubs and Murphy USA gas/diesel in the USA and Canada.
# Note that Gas/Diesel and No Over Night Parking (NOP) are indicated if
# known. These data can be obtained from the site
# <http://www.poi-factory.com/node/25560>.
#
#
# **Before you start.** You started cleaning this data set in Activity 4.1.  Start by copying over your code and fixing the encoding issue.

# %%
import pandas as pd
pd.set_option("display.max_colwidth", None) # don't cut off text
pd.set_option("display.max_columns", None) # horizontal scroll columns instead of wrapping around
import collections
collections.Iterable = collections.abc.Iterable # python 3.10 fix for dfply if_else
from dfply import *
from more_dfply import case_when
from more_dfply.facets import text_filter
import re

# %%
# Notepad indicates this file is ANSI, which means "pretty much whatever the system wants"
# cp1252 is for Western European Languages, so it ought to suffice for US/Canada data
walmart = pd.read_csv("./data/Walmart_United_States_&_Canada.csv",
                      names = ["Lat", "Long", "Description", "AddressPhone"],
                      encoding="cp1252")
walmart.head()
# Out:
#           Lat       Long                      Description  \
# 0 -114.005671  51.262567      Walmart Supercentre; #1050,
# 1 -111.900542  50.577939      Walmart Supercentre; #3658,
# 2 -114.039133  51.107253      Walmart Supercentre; #3013,
# 3 -114.138488  51.040871  Walmart Supercentre; #3009,Gas,
# 4 -114.028603  50.930551                  Walmart; #1144,
#
#                                                    AddressPhone
# 0            2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-1295
# 1                917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111
# 2     1110 57th Ave NE,Calgary ,(NOP),AB T2E 9B7,(403) 730-0990
# 3        1212 37 St SW,Calgary ,(NOP),AB T3C 1S3,(403) 242-2205
# 4  1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,(403) 225-6638

# %%
# Copy your code from Activity 4.1 here
wm_cleaned = (walmart
                >> mutate(Description = if_else(X.Description.str.contains("; Supercenter"),
                                              X.Description.str.replace(";", ""), X.Description)) # fix one weird case
                >> mutate(Description = X.Description.str.replace(';', ','))
                >> mutate(Store_type = X.Description.str.split(',').str.get(0),
                         Store_number = X.Description.str.split(',').str.get(1),
                         Gas = X.Description.str.split(',').str.get(2))
                >> mutate(Gas = X.Gas.map(lambda s: s if s else "None")) # replace empty strings in Gas field
)
wm_cleaned.head()
# Out:
#           Lat       Long                      Description  \
# 0 -114.005671  51.262567      Walmart Supercentre, #1050,
# 1 -111.900542  50.577939      Walmart Supercentre, #3658,
# 2 -114.039133  51.107253      Walmart Supercentre, #3013,
# 3 -114.138488  51.040871  Walmart Supercentre, #3009,Gas,
# 4 -114.028603  50.930551                  Walmart, #1144,
#
#                                                    AddressPhone  \
# 0            2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-1295
# 1                917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111
# 2     1110 57th Ave NE,Calgary ,(NOP),AB T2E 9B7,(403) 730-0990
# 3        1212 37 St SW,Calgary ,(NOP),AB T3C 1S3,(403) 242-2205
# 4  1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,(403) 225-6638
#
#             Store_type Store_number   Gas
# 0  Walmart Supercentre        #1050  None
# 1  Walmart Supercentre        #3658  None
# 2  Walmart Supercentre        #3013  None
# 3  Walmart Supercentre        #3009   Gas
# 4              Walmart        #1144  None

# %%
# verify the weird case was handled
walmart.iloc[[893]]
# Out:
#             Lat       Long                  Description  \
# 893 -120.419884  34.919944  Walmart; Supercenter,#2507,
#
#                                                   AddressPhone
# 893  2220 S Bradley,Santa Maria,CA,93455 ,(NOP),(805) 349-7885

# %%
wm_cleaned.iloc[[893]]
# Out:
#             Lat       Long                 Description  \
# 893 -120.419884  34.919944  Walmart Supercenter,#2507,
#
#                                                   AddressPhone  \
# 893  2220 S Bradley,Santa Maria,CA,93455 ,(NOP),(805) 349-7885
#
#               Store_type Store_number   Gas
# 893  Walmart Supercenter        #2507  None

# %% [markdown]
# 1.  Some of the address columns contain `(NOP)` to indicated *No overnight parking*.  Extract this information into a new indicator column, then remove it from the address column.

# %%
# yes, bad variables names. But it's kind of necessary to be able to preserve changes while developing one cell at a time.
# We could do in-place modification but that's also messy.
# At the end, we'll combine into a single pipe anyways.

wm1 = (wm_cleaned
          >> mutate(OvernightParking = 1 - X.AddressPhone.str.count("(NOP)"),
                    AddressPhone = X.AddressPhone.str.replace("\(NOP\),?", "", regex=True)
                   ) 
)
wm1.head()
# Out:
#           Lat       Long                      Description  \
# 0 -114.005671  51.262567      Walmart Supercentre, #1050,
# 1 -111.900542  50.577939      Walmart Supercentre, #3658,
# 2 -114.039133  51.107253      Walmart Supercentre, #3013,
# 3 -114.138488  51.040871  Walmart Supercentre, #3009,Gas,
# 4 -114.028603  50.930551                  Walmart, #1144,
#
#                                                    AddressPhone  \
# 0            2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-1295
# 1                917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111
# 2           1110 57th Ave NE,Calgary ,AB T2E 9B7,(403) 730-0990
# 3              1212 37 St SW,Calgary ,AB T3C 1S3,(403) 242-2205
# 4  1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,(403) 225-6638
#
#             Store_type Store_number   Gas  OvernightParking
# 0  Walmart Supercentre        #1050  None                 1
# 1  Walmart Supercentre        #3658  None                 1
# 2  Walmart Supercentre        #3013  None                 0
# 3  Walmart Supercentre        #3009   Gas                 0
# 4              Walmart        #1144  None                 1

# %% [markdown]
# 2.  The address column contains the phone number of most of the stores.  Extract this information into a new column.  There are some issue with different patterns, so use the divide-and-conquer approach is advised.

# %%
# Your code here
(wm1
    >> select(X.AddressPhone)
    >> filter_by(~text_filter(X.AddressPhone, "\(\d{3}\)\s+\d{3}-\d{4}", regex=True)) # vast majority of cases
    >> filter_by(~text_filter(X.AddressPhone, "\(\d{3}\)\s+\d{3} \d{4}", regex=True)) # space instead of dash
    >> filter_by(~text_filter(X.AddressPhone, "\(\d{3}\)\d{3}-\d{4}", regex=True)) # no initial space
    >> filter_by(~text_filter(X.AddressPhone, "\(\d{3}0\s+\d{3}-\d{4}", regex=True)) # end parenthesis replaced with 0
#    >> filter_by(text_filter(X.AddressPhone, "\(\d{3}\)\d{3}-\d{4}", regex=True))
)
# Out:
#                                                                     AddressPhone
# 354                          8303 Rogers Ave,Fort Smith,AR,72903 ,,(479) 452-161
# 1921                                   510 Ave C,Denison,IA,51442,(712_263-2000,
# 2633                      6225 Coliseum Blvd,Alexandria,LA,71303 ,,(318-448-8881
# 3733         1318 Mebane Oaks Rd; I-40 Exit 154,Mebane,NC,27302 ,,(919) 30400171
# 3994                             950 Rte 37 W,Toms River,NJ,08755,(732_349-6000,
# 4232                         1134 Wicker St,Ticonderoga,NY,12883 ,,(518(585-3060
# 4543                       7520 E Reno Ave,Midwest City,OK,73110 ,(405( 455-4070
# 4796                100 Stonebridge Blvd,Wasaga Beach ,ON L9Z 0C1,(705 )442-7100
# 5017                1333 Boul Michele-Bohec,Blainville,(450_ 419-5930,QC J7C 0M4
# 6135                                                6040 Coit Rd,Plano,TX,75023,
# 6193                      3440 S Bryant Blvd,San Angelo,TX,76903 ,,(325) 26-6599
# 6462  17041 Jefferson Davis Hwy; I-95 Exit 152,Dumfries,VA,22026 ,(703) 22104116

# %%
def get_last(item, sep=","):
    # split on sep and return the last element
    return item.split(sep)[-1]

# %%
(wm1
    >> mutate(PhoneNumber = case_when((text_filter(X.AddressPhone, "\(\d{3}\)\s+\d{3}-\d{4}", regex=True),
                                            X.AddressPhone.map(get_last)),
                                      (text_filter(X.AddressPhone, "\(\d{3}\)\s+\d{3} \d{4}", regex=True),
                                            X.AddressPhone.map(get_last).str.replace("\s+(\d{4})$", "-\\1", regex=True)),
                                      (text_filter(X.AddressPhone, "\(\d{3}\)\d{3}-\d{4}", regex=True),
                                            X.AddressPhone.map(get_last).str.replace(")", ") ", regex=False)),
                                      (text_filter(X.AddressPhone, "\(\d{3}0 \d{3}-\d{4}", regex=True),
                                            X.AddressPhone.map(get_last).str.replace("^\((\d{3})0", r"(\1)", regex=True)),
                                      (True, "Missing or invalid phone")
                                     )
             )
     >> filter_by(text_filter(X.AddressPhone, "\(\d{3}0 \d{3}-\d{4}", regex=True))
#     >> filter_by(text_filter(X.PhoneNumber, "no phone"))
).head()
# Out:
#              Lat       Long                  Description  \
# 207   -88.194899  30.679921         Wm Nbrhd Mkt, #4648,
# 973  -104.793389  39.625883         Wm Nbrhd Mkt, #3126,
# 3569  -66.092624  45.255944              Walmart, #1175,
# 3812  -82.578265  35.703458  Walmart Supercenter, #4334,
#
#                                                                     AddressPhone  \
# 207                            6575 Airport Blvd,Mobile,AL,36608 ,(2510 370-9845
# 973                   16746 E Smokey Hill Rd,Centennial,CO,80015 ,(3030 305-1110
# 3569                    621 Fairville Blvd,Saint John ,NB E2M 4X5,(5060 693-1668
# 3812  25 Northbridge Commons; I-26 Exit 19,Weaverville,NC,28787 ,,(8280 645-5028
#
#                Store_type Store_number   Gas  OvernightParking     PhoneNumber
# 207          Wm Nbrhd Mkt        #4648  None                 0  (251) 370-9845
# 973          Wm Nbrhd Mkt        #3126  None                 0  (303) 305-1110
# 3569              Walmart        #1175  None                 1  (506) 693-1668
# 3812  Walmart Supercenter        #4334  None                 1  (828) 645-5028

# %%
# We could continue in this pattern, but we're basically down to 1 case per pattern and several more patterns to go
# I observed that you can discern the three fields of the phone number in just about any pattern
# If we can get that, we can make it comply with our formatting
# The only ones that don't match are invalid (missing a digit or just entirely missing)
(wm1
    >> select(X.AddressPhone)
    >> filter_by(~text_filter(X.AddressPhone, "\(\d{3}.*\d{3}.*\d{4}", regex=True)) # vast majority of cases)
)
# Out:
#                                                 AddressPhone
# 354      8303 Rogers Ave,Fort Smith,AR,72903 ,,(479) 452-161
# 6135                            6040 Coit Rd,Plano,TX,75023,
# 6193  3440 S Bryant Blvd,San Angelo,TX,76903 ,,(325) 26-6599

# %%
# Field either contains a phone number, in which case we can then extract the parts and format as desired
#     or it does not, in which case we should mark it as such

#The opening parenthesis is important to keep it from starting too early, and all phone numbers had this anyway
wm2 = (wm1
    >> mutate(PhoneNumber = X.AddressPhone.str.extract("(\(\d{3}.*\d{3}.*\d{4})"))
    >> mutate(PhoneNumber = if_else(X.PhoneNumber.isna(), # did not contain the pattern
                                  "Missing or invalid phone",
                                  X.PhoneNumber.str.replace("\((\d{3}).*(\d{3}).*(\d{4})", r"(\1) \2-\3", regex=True)
                                  ))
)
wm2.head()
# Out:
#           Lat       Long                      Description  \
# 0 -114.005671  51.262567      Walmart Supercentre, #1050,
# 1 -111.900542  50.577939      Walmart Supercentre, #3658,
# 2 -114.039133  51.107253      Walmart Supercentre, #3013,
# 3 -114.138488  51.040871  Walmart Supercentre, #3009,Gas,
# 4 -114.028603  50.930551                  Walmart, #1144,
#
#                                                    AddressPhone  \
# 0            2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-1295
# 1                917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111
# 2           1110 57th Ave NE,Calgary ,AB T2E 9B7,(403) 730-0990
# 3              1212 37 St SW,Calgary ,AB T3C 1S3,(403) 242-2205
# 4  1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,(403) 225-6638
#
#             Store_type Store_number   Gas  OvernightParking     PhoneNumber
# 0  Walmart Supercentre        #1050  None                 1  (403) 945-1295
# 1  Walmart Supercentre        #3658  None                 1  (403) 793-2111
# 2  Walmart Supercentre        #3013  None                 0  (403) 730-0990
# 3  Walmart Supercentre        #3009   Gas                 0  (403) 242-2205
# 4              Walmart        #1144  None                 1  (403) 225-6638

# %%
# What about the weird cases?
wm2.iloc[[354, 6135, 6193]]
# Out:
#              Lat       Long                     Description  \
# 354   -94.339372  35.347970  Murphy: USA, #7133,Gas/Diesel,
# 6135  -96.769302  33.054745  Walmart Fuel Center,#0997,Gas,
# 6193 -100.441994  31.426951     Walmart Supercenter, #7281,
#
#                                                 AddressPhone  \
# 354      8303 Rogers Ave,Fort Smith,AR,72903 ,,(479) 452-161
# 6135                            6040 Coit Rd,Plano,TX,75023,
# 6193  3440 S Bryant Blvd,San Angelo,TX,76903 ,,(325) 26-6599
#
#                Store_type Store_number         Gas  OvernightParking  \
# 354           Murphy: USA        #7133  Gas/Diesel                 1
# 6135  Walmart Fuel Center        #0997         Gas                 1
# 6193  Walmart Supercenter        #7281        None                 1
#
#                    PhoneNumber
# 354   Missing or invalid phone
# 6135  Missing or invalid phone
# 6193  Missing or invalid phone

# %% [markdown]
# 3.  Extract the country from the address column.

# %%
# observe some addresses to look for the pattern
wm2.AddressPhone.sample(15)
# Out:
# 4380                       1640 S Washington St,Millersburg,OH,44654 ,,(330) 674-2888
# 5295                               1602 W Market St,Bolivar,TN,38008 ,,(731) 659-3900
# 3726                       2985 E Elizabethtown Rd,Lumberton,NC,28358 ,(910) 887-6107
# 5626                           951 SW Wilshire Blvd,Burleson,TX,76028 ,(817) 572-9574
# 4563                   10307 S Western Avenue,Oklahoma City,OK,73139 ,,(405) 692-6267
# 3700                         1170 Western Blvd,Jacksonville,NC,28546 ,,(910) 346-2148
# 2931                            3549 Russett Green E,Laurel,MD,20724 ,,(301) 604-0180
# 6654               1486 Dike Access Rd; I-5 Exit 22,Woodland,WA,98674 ,(360) 841-9131
# 476                           1900 E Chandler Blvd,Chandler,AZ,85225 ,,(480) 448-4322
# 2188                  420 Weber Rd; I-55 Exit 263,Romeoville,IL,60446 ,(815) 439-1666
# 5160                        5009 Old Buncombre Rd,Greenville,SC,29617 ,(864) 605-6309
# 6344    6760 Westworth Blvd; I-30 Exit 78,Westworth Village,TX,76114 ,,(817) 763-9621
# 1152                          1803 N Highland Ave,Clearwater,FL,33755 ,(727) 441-4320
# 1936                                840 S Oak St,Iowa Falls,IA,50126 ,,(641) 648-5145
# 57                               6809 Hwy 16A W,Vegreville ,AB T9C 0A2,(780) 632-6016
# Name: AddressPhone, dtype: object

# %%
# examine a pattern idea
wm2 >> filter_by(~X.AddressPhone.str.contains(",[A-Z]{2},", regex=True))
# Out:
#              Lat       Long                      Description  \
# 0    -114.005671  51.262567      Walmart Supercentre, #1050,
# 1    -111.900542  50.577939      Walmart Supercentre, #3658,
# 2    -114.039133  51.107253      Walmart Supercentre, #3013,
# 3    -114.138488  51.040871  Walmart Supercentre, #3009,Gas,
# 4    -114.028603  50.930551                  Walmart, #1144,
# ...          ...        ...                              ...
# 5279 -106.642526  52.087947      Walmart Supercentre, #5878,
# 5280 -107.774910  50.306610      Walmart Supercentre, #3099,
# 5281 -103.866420  49.660470                  Walmart, #5790,
# 5282 -102.444819  51.204644      Walmart Supercentre, #3176,
# 6815 -135.069300  60.733253      Walmart Supercentre, #3191,
#
#                                                       AddressPhone  \
# 0               2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-1295
# 1                   917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111
# 2              1110 57th Ave NE,Calgary ,AB T2E 9B7,(403) 730-0990
# 3                 1212 37 St SW,Calgary ,AB T3C 1S3,(403) 242-2205
# 4     1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,(403) 225-6638
# ...                                                            ...
# 5279      3035 Clarence Ave S,Saskatoon ,SK S7T 0B6,(306) 653-8200
# 5280        1800 22nd Ave,Swift Current ,SK S9H 0E5,(306) 778-3489
# 5281              1000 Sims Ave,Weyburn ,SK S4H 3N9,(306) 842-6030
# 5282            240 Hamilton Rd,Yorkton ,SK S3N 4C6,(306) 782-9820
# 6815          9021 Quartz Rd,Whitehorse ,YT Y1A 4P9,(867) 667-2652
#
#                Store_type Store_number   Gas  OvernightParking     PhoneNumber
# 0     Walmart Supercentre        #1050  None                 1  (403) 945-1295
# 1     Walmart Supercentre        #3658  None                 1  (403) 793-2111
# 2     Walmart Supercentre        #3013  None                 0  (403) 730-0990
# 3     Walmart Supercentre        #3009   Gas                 0  (403) 242-2205
# 4                 Walmart        #1144  None                 1  (403) 225-6638
# ...                   ...          ...   ...               ...             ...
# 5279  Walmart Supercentre        #5878  None                 0  (306) 653-8200
# 5280  Walmart Supercentre        #3099  None                 1  (306) 778-3489
# 5281              Walmart        #5790  None                 1  (306) 842-6030
# 5282  Walmart Supercentre        #3176  None                 1  (306) 782-9820
# 6815  Walmart Supercentre        #3191  None                 1  (867) 667-2652
#
# [410 rows x 9 columns]

# %%
# US addresses have a 2-letter state abbreviation set off by commas, Canadian addresses do not
wm3 = (wm2
    >> mutate(Country = if_else(X.AddressPhone.str.contains(",[A-Z]{2},"), "USA", "Canada"))
)
wm3.sample(10)
# Out:
#             Lat       Long                             Description  \
# 5848 -96.107452  33.093896             Walmart Supercenter, #0427,
# 3006 -83.441765  42.558807             Walmart Supercenter, #2618,
# 5070 -74.016910  45.760800             Walmart Supercentre, #3190,
# 5625 -97.339432  32.529201          Murphy: USA, #5627,Gas/Diesel,
# 5684 -97.338653  32.576217  Walmart Supercenter, #3631,Gas/Diesel,
# 3107 -85.654857  41.941804             Walmart Supercenter, #3791,
# 5159 -82.268640  34.860020             Walmart Supercenter, #4583,
# 3411 -90.881064  38.813326           Sam's Club, #4875,Gas/Diesel,
# 5298 -82.236900  36.544304          Murphy: USA, #6971,Gas/Diesel,
# 4174 -77.725081  43.214631                         Walmart, #1610,
#
#                                                                  AddressPhone  \
# 5848     7401 Interstate 30; I-30 Exit 89,Greenville,TX,75402 ,(903) 455-1792
# 3006                 3301 Pontiac Trail Rd,Commerce,MI,48382 ,,(248) 668-0274
# 5070         1030 Boul Du Grand-Héron,Saint-Jérôme ,QC J7Y 5K8,(450) 438-6776
# 5625                  921 SW Wilshire Blvd,Burleson,TX,76028 ,,(817) 426-1505
# 5684                 1221 FM 1187; I-35 Exit,Crowley,TX,76036 ,(682) 233-7834
# 3107                  101 S Tolbert Dr,Three Rivers,MI,49093 ,,(269) 273-7820
# 5159        3925 Pelham Rd; I-85 Exit 54,Greenville,SC,29615 ,,(864) 288-8081
# 3411  3055 Bear Creek Dr: I-70 Exit 208,Wentzville,MO,63385 .,,(636) 698-9774
# 5298          260 Century Blvd; I-81 Exit 1,Bristol,TN,37620 ,,(423) 968-7395
# 4174                 100 Elm Ridge Center Dr,Greece,NY,14626 ,,(585) 227-0720
#
#                Store_type Store_number         Gas  OvernightParking  \
# 5848  Walmart Supercenter        #0427        None                 0
# 3006  Walmart Supercenter        #2618        None                 1
# 5070  Walmart Supercentre        #3190        None                 1
# 5625          Murphy: USA        #5627  Gas/Diesel                 1
# 5684  Walmart Supercenter        #3631  Gas/Diesel                 0
# 3107  Walmart Supercenter        #3791        None                 1
# 5159  Walmart Supercenter        #4583        None                 1
# 3411           Sam's Club        #4875  Gas/Diesel                 1
# 5298          Murphy: USA        #6971  Gas/Diesel                 1
# 4174              Walmart        #1610        None                 1
#
#          PhoneNumber Country
# 5848  (903) 455-1792     USA
# 3006  (248) 668-0274     USA
# 5070  (450) 438-6776  Canada
# 5625  (817) 426-1505     USA
# 5684  (682) 233-7834     USA
# 3107  (269) 273-7820     USA
# 5159  (864) 288-8081     USA
# 3411  (636) 698-9774     USA
# 5298  (423) 968-7395     USA
# 4174  (585) 227-0720     USA

# %% [markdown]
# 4.  Extract the state or province from the address columns

# %%
# Pattern is clear from previous step
wm4 = (wm3 >>
    mutate(StateOrProvince = X.AddressPhone.str.extract(",([A-Z]{2})"))
)
wm4.sample(10)
# Out:
#              Lat       Long                     Description  \
# 6645 -122.480896  47.239844     Walmart Supercenter, #4137,
# 6546  -80.088733  37.289302     Walmart Supercenter, #1309,
# 6218  -98.548481  29.356398          Sam's Club, #8264,Gas,
# 2211  -87.796047  41.597997              Sam's Club, #6485,
# 2797  -93.711365  32.430073         Murphy: USA, #5673,Gas,
# 3022  -83.648486  42.938093     Walmart Supercenter, #3726,
# 5036  -70.910627  45.594042                 Walmart, #1019,
# 1688  -82.969864  32.549038  Murphy: USA, #7468,Gas/Diesel,
# 3910  -71.069762  43.027671     Walmart Supercenter, #3535,
# 6745  -90.508121  44.019824     Walmart Supercenter, #0965,
#
#                                                                   AddressPhone  \
# 6645            1965 S Union Ave; I-5 Exit 132,Tacoma,WA,98405 ,(253) 414-9526
# 6546             1851 W Main St; I-81 Exit 137,Salem,VA,24153 ,,(540) 375-2919
# 6218  3150 Sw Military Dr; I-35 Exit 148,San Antonio,TX,78224 ,,(210) 927-3593
# 2211                   16100 Harlem AvE ,Tinley Park,IL,60477 ,,(708) 429-6069
# 2797                       8020 Youree Dr,Shreveport,LA,71115 ,,(318) 797-7803
# 3022                    6170 S Saginaw Rd,Grand Blanc,MI,48439 ,(810) 603-9739
# 5036                    3130 Rue Laval,Lac-Megantic ,QC G6B 1A4,(819) 583-2882
# 1688                            2419 Hwy 80 W,Dublin,GA,31021 ,,(478) 272-3505
# 3910                         35 Fresh River Rd,Epping,NH,03042 ,(603) 679-5919
# 6745           222 W Mccoy Blvd; I-94 Exit 143,Tomah,WI,54660 ,,(608) 372-7900
#
#                Store_type Store_number         Gas  OvernightParking  \
# 6645  Walmart Supercenter        #4137        None                 0
# 6546  Walmart Supercenter        #1309        None                 1
# 6218           Sam's Club        #8264         Gas                 1
# 2211           Sam's Club        #6485        None                 1
# 2797          Murphy: USA        #5673         Gas                 1
# 3022  Walmart Supercenter        #3726        None                 0
# 5036              Walmart        #1019        None                 1
# 1688          Murphy: USA        #7468  Gas/Diesel                 1
# 3910  Walmart Supercenter        #3535        None                 0
# 6745  Walmart Supercenter        #0965        None                 1
#
#          PhoneNumber Country StateOrProvince
# 6645  (253) 414-9526     USA              WA
# 6546  (540) 375-2919     USA              VA
# 6218  (210) 927-3593     USA              TX
# 2211  (708) 429-6069     USA              IL
# 2797  (318) 797-7803     USA              LA
# 3022  (810) 603-9739     USA              MI
# 5036  (819) 583-2882  Canada              QC
# 1688  (478) 272-3505     USA              GA
# 3910  (603) 679-5919     USA              NH
# 6745  (608) 372-7900     USA              WI

# %% [markdown]
# 5. Combine all of your transformations into one pipe, then re-factor your code to be more readable.

# %%
def get_last(item, sep=","):
    # split on sep and return the last element
    return item.split(sep)[-1]

# %%
# One pipe for all transformations.
(walmart
    >> mutate(Description = if_else(X.Description.str.contains("; Supercenter"),
                                  X.Description.str.replace(";", ""), X.Description)) # fix one weird case
    >> mutate(Description = X.Description.str.replace(';', ',')) # standardize formatting
    >> mutate(Store_type = X.Description.str.split(',').str.get(0),
              Store_number = X.Description.str.split(',').str.get(1),
              Gas = X.Description.str.split(',').str.get(2))
    >> mutate(Gas = X.Gas.map(lambda s: s if s else "None")) # replace empty strings in Gas field
    >> mutate(OvernightParking = 1 - X.AddressPhone.str.count("(NOP)"),
              AddressPhone = X.AddressPhone.str.replace("\(NOP\),?", "", regex=True))
    >> mutate(PhoneNumber = X.AddressPhone.str.extract("(\(\d{3}.*\d{3}.*\d{4})"))
    >> mutate(PhoneNumber = if_else(X.PhoneNumber.isna(), # did not contain the pattern
                                  "Missing or invalid phone",
                                  X.PhoneNumber.str.replace("\((\d{3}).*(\d{3}).*(\d{4})", r"(\1) \2-\3", regex=True)))
    >> mutate(Country = if_else(X.AddressPhone.str.contains(",[A-Z]{2},"), "USA", "Canada"))
    >> mutate(StateOrProvince = X.AddressPhone.str.extract(",([A-Z]{2})"))
)
# Out:
#              Lat       Long                      Description  \
# 0    -114.005671  51.262567      Walmart Supercentre, #1050,
# 1    -111.900542  50.577939      Walmart Supercentre, #3658,
# 2    -114.039133  51.107253      Walmart Supercentre, #3013,
# 3    -114.138488  51.040871  Walmart Supercentre, #3009,Gas,
# 4    -114.028603  50.930551                  Walmart, #1144,
# ...          ...        ...                              ...
# 6811 -107.209281  41.792084  Walmart Supercenter, #4471,Gas,
# 6812 -108.379227  43.042858      Walmart Supercenter, #1457,
# 6813 -109.251020  41.579761      Walmart Supercenter, #1461,
# 6814 -106.940967  44.779474      Walmart Supercenter, #1508,
# 6815 -135.069300  60.733253      Walmart Supercentre, #3191,
#
#                                                                 AddressPhone  \
# 0                         2881 Main St SW,Airdrie ,AB T4B 3G5,(403) 945-1295
# 1                             917 3rd St W,Brooks ,AB T1R 1L5,(403) 793-2111
# 2                        1110 57th Ave NE,Calgary ,AB T2E 9B7,(403) 730-0990
# 3                           1212 37 St SW,Calgary ,AB T3C 1S3,(403) 242-2205
# 4               1221 Canyon Meadows Dr SE,Calgary ,AB T2J 6G2,(403) 225-6638
# ...                                                                      ...
# 6811        2390 E Cedar St; I-80 Exit 214,Rawlins,WY,82301 ,,(307) 417-3001
# 6812                  1733 N Federal Blvd,Riverton,WY,82501 ,,(307) 856-3261
# 6813  201 Gateway Blvd; I-80 Exit 102,Rock Springs,WY,82901 ,,(307) 362-1957
# 6814        1695 Coffeen Ave; I-90 Exit 25,Sheridan,WY,82801 ,(307) 674-6492
# 6815                    9021 Quartz Rd,Whitehorse ,YT Y1A 4P9,(867) 667-2652
#
#                Store_type Store_number   Gas  OvernightParking  \
# 0     Walmart Supercentre        #1050  None                 1
# 1     Walmart Supercentre        #3658  None                 1
# 2     Walmart Supercentre        #3013  None                 0
# 3     Walmart Supercentre        #3009   Gas                 0
# 4                 Walmart        #1144  None                 1
# ...                   ...          ...   ...               ...
# 6811  Walmart Supercenter        #4471   Gas                 1
# 6812  Walmart Supercenter        #1457  None                 1
# 6813  Walmart Supercenter        #1461  None                 1
# 6814  Walmart Supercenter        #1508  None                 0
# 6815  Walmart Supercentre        #3191  None                 1
#
#          PhoneNumber Country StateOrProvince
# 0     (403) 945-1295  Canada              AB
# 1     (403) 793-2111  Canada              AB
# 2     (403) 730-0990  Canada              AB
# 3     (403) 242-2205  Canada              AB
# 4     (403) 225-6638  Canada              AB
# ...              ...     ...             ...
# 6811  (307) 417-3001     USA              WY
# 6812  (307) 856-3261     USA              WY
# 6813  (307) 362-1957     USA              WY
# 6814  (307) 674-6492     USA              WY
# 6815  (867) 667-2652  Canada              YT
#
# [6816 rows x 11 columns]

# %%
# Refactored coded here (definitions/lambdas then the pipe)
phone_capture_full = re.compile("(\(\d{3}.*?\d{3}.*?\d{4})")
phone_capture_parts = re.compile("\((\d{3}).*?(\d{3}).*?(\d{4})")
phone_formatting = r"(\1) \2-\3" # based on the vast majority of the forms

state_pattern = re.compile(",[A-Z]{2},")
stateprovince_capture = re.compile(",([A-Z]{2})")

@dfpipe
def fix_anomaly(df):
    # One entry contains "Walmart; Supercenter" which needs to be fixed
    # However, semicolons are regularly used as delimiters, so we can't indiscriminately replace them
    return (df >> mutate(Description = if_else(X.Description.str.contains("; Supercenter"),
                                  X.Description.str.replace(";", ""), X.Description)))
@dfpipe
def standardize_description_delimiter(df):
    return (df >> mutate(Description = X.Description.str.replace(';', ',')))

def replace_missing(s, on_missing): return s if s else on_missing

description_fields = ["StoreType", "StoreNumber", "Gas"]
description_extraction = {f"{c}" : X["Description"].str.split(',').str.get(i).apply(replace_missing, args=("None",))
                          for i, c in enumerate(description_fields)}

def get_indicator_value(s, value, reverse=False):
    if reverse:
        return int(value not in s)
    else:
        return int(value in s)

def create_indicator(col, value, reverse=False):
    # create an indicator column based on containing the provided value
    # Use reverse=True to create a negative indicator (1 if value is not present)
    return col.apply(get_indicator_value, args=(value,), reverse=reverse)    

def format_phone(s): return re.sub(phone_capture_parts, phone_formatting, s)

def get_and_format_phone(s):
    raw_phone = m.group() if (m:=re.search(phone_capture_full, s)) else "Missing or invalid phone"
    return format_phone(raw_phone)

def detect_country(col):
    return col.map(lambda s: "USA" if state_pattern.search(s) else "Canada")

def extract_state(col):
    return col.str.extract(stateprovince_capture)

wm_finished = (walmart
    >> fix_anomaly()
    >> standardize_description_delimiter()
    >> mutate(**description_extraction)
    >> mutate(OvernightParking = create_indicator(X.AddressPhone, "(NOP)", reverse=True),
              PhoneNumber = X.AddressPhone.map(get_and_format_phone),
              Country = detect_country(X.AddressPhone),
              StateOrProvince = extract_state(X.AddressPhone))
)
wm_finished.sample(10)
# Out:
#              Lat       Long                             Description  \
# 6380 -111.711053  40.273414             Walmart Supercenter, #1768,
# 1471  -81.012795  29.116841          Murphy: USA, #7544,Gas/Diesel,
# 6444  -76.225073  36.743022                    Wm Nbrhd Mkt, #3299,
# 5308  -85.385487  35.020699  Walmart Supercenter, #3660,Gas/Diesel,
# 2812  -90.815808  29.807642          Murphy: USA, #5817,Gas/Diesel,
# 5282 -102.444819  51.204644             Walmart Supercentre, #3176,
# 5824  -96.652141  32.862091             Walmart Supercenter, #1800,
# 5015  -68.256474  49.200890                         Walmart, #3002,
# 5307  -85.376054  35.018647          Murphy: USA, #7587,Gas/Diesel,
# 6385 -110.789621  39.596304             Walmart Supercenter, #1573,
#
#                                                                  AddressPhone  \
# 6380         1355 S Sandhill Rd; I-15 Exit 269,Orem,UT,84058 ,,(801) 221-0600
# 1471  1596 Dunlawton Ave; I-95 Exit 256,Port Orange,FL,32127 ,,(386) 761-7010
# 6444              475 Kempsville Rd,Chesapeake,VA,23320 ,(NOP),(410) 454-0021
# 5308   3550 Cummings Hwy; I-24 Exit 174,Chattanooga,TN,37419 ,,(423) 821-1556
# 2812                     412 N Canal Blvd,Thibodaux,LA,70301 ,,(985) 446-6355
# 5282                       240 Hamilton Rd,Yorkton ,SK S3N 4C6,(306) 782-9820
# 5824   1801 MarketPL Dr; I-635 Exit 11,Garland,TX,75041 ,(NOP),(972) 279-8700
# 5015                 630 Boul Laflèche,Baie-Comeau ,QC G5C 2Y3,(418) 589-9971
# 5307   3538 Cummings Hwy; I-24 Exit 174,Chattanooga,TN,37419 ,,(423) 875-7055
# 6385                             255 S Hwy 55,Price,UT,84501 ,,(435) 637-6712
#
#                 StoreType StoreNumber         Gas  OvernightParking  \
# 6380  Walmart Supercenter       #1768        None                 1
# 1471          Murphy: USA       #7544  Gas/Diesel                 1
# 6444         Wm Nbrhd Mkt       #3299        None                 0
# 5308  Walmart Supercenter       #3660  Gas/Diesel                 1
# 2812          Murphy: USA       #5817  Gas/Diesel                 1
# 5282  Walmart Supercentre       #3176        None                 1
# 5824  Walmart Supercenter       #1800        None                 0
# 5015              Walmart       #3002        None                 1
# 5307          Murphy: USA       #7587  Gas/Diesel                 1
# 6385  Walmart Supercenter       #1573        None                 1
#
#          PhoneNumber Country StateOrProvince
# 6380  (801) 221-0600     USA              UT
# 1471  (386) 761-7010     USA              FL
# 6444  (410) 454-0021     USA              VA
# 5308  (423) 821-1556     USA              TN
# 2812  (985) 446-6355     USA              LA
# 5282  (306) 782-9820  Canada              SK
# 5824  (972) 279-8700     USA              TX
# 5015  (418) 589-9971  Canada              QC
# 5307  (423) 875-7055     USA              TN
# 6385  (435) 637-6712     USA              UT

# %%
# Write the results to a file named walmart_locations_clean.csv.  Make sure to include this file in your submission on D2L
wm_finished.to_csv("./data/walmart_locations_clean.csv")
